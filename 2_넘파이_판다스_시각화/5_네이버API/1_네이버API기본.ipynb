# %%
# # 네이버 검색 API 예제 - 블로그 검색
# import os
# import sys
# import urllib.request
# client_id = "KAuvK932dShzAKri5hVS"
# client_secret = "RYoovIW_cv"
# encText = urllib.parse.quote("반도체")
# url = f"https://openapi.naver.com/v1/search/blog?query=" + encText +"&display=100&starts={}" # JSON 결과 "&display=100"로 바꿀 수 있음.
# # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
# request = urllib.request.Request(url)
# request.add_header("X-Naver-Client-Id",client_id)
# request.add_header("X-Naver-Client-Secret",client_secret)
# response = urllib.request.urlopen(request)
# rescode = response.getcode()
# if(rescode==200):
#     response_body = response.read()
#     print(response_body.decode('utf-8'))
# else:
#     print("Error Code:" + rescode)

# %%
import os
import sys
import urllib.request

client_id = "KAuvK932dShzAKri5hVS"
client_secret = "RYoovIW_cv"
encText = urllib.parse.quote("반도체")

for start in range(1, 1001, 100):
    url = f"https://openapi.naver.com/v1/search/blog?query={encText}&display=100&start={start}"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if rescode == 200:
        response_body = response.read()
        print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + str(rescode))
# Out:
# {
# 	"lastBuildDate":"Thu, 20 Jun 2024 15:57:44 +0900",
# 	"total":280308,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"윤석열-<b>홍준표<\/b> 만찬회동의 블랙코미디와, 박영선・양정철의... ",
# 			"link":"https:\/\/buck4514.tistory.com\/664",
# 			"description":"윤석열-<b>홍준표<\/b> 만찬회동의 블랙코미디와, 박영선・양정철의 총리・비서실장 기용설(説)의 웃픈 해프닝 윤성녈과 '돼지발정제의 남자' <b>홍준표<\/b>가 4월 16일 장장 4시간에 걸쳐 만찬회동을 가졌습니다.... ",
# 			"bloggername":"The Call of The Wildⓣ",
# 			"bloggerlink":"https:\/\/buck4514.tistory.com\/",
# 			"postdate":"20240419"
# 		},
# 		{
# 			"title":"왜 다시 한동훈인가? (김무성·<b>홍준표<\/b>·황교안과 달랐다)",
# 			"link":"https:\/\/blog.naver.com\/jpk0107\/223451119393",
# 			"description":"2016년 총선의 김무성 대표, 2018년 지방선거의 <b>홍준표<\/b> 대표, 2020년 총선의 황교안 대표는 선거 패배 직후... 2018년 지방선거의 <b>홍준표<\/b> 대표는 '막말 퍼레이드'로 당 지지율에 치명상을 입히며 전멸시켰습니다.... ",
# 			"bloggername":"고모군의 정치바로세우기",
# 			"bloggerlink":"blog.naver.com\/jpk0107",
# 			"postdate":"20240519"
# 		},
# 		{
# 			"title":"<b>홍준표<\/b>, 윤석열 탈당 신당창당은 누구를 발언인가? 본인을 위한... ",
# ...

# %%
import json
text_data = response_body.decode('utf-8')
text_data
# Out:
# '{\n\t"lastBuildDate":"Thu, 20 Jun 2024 15:57:48 +0900",\n\t"total":280308,\n\t"start":901,\n\t"display":100,\n\t"items":[\n\t\t{\n\t\t\t"title":"<b>홍준표<\\/b> 막말에 대한 댓글 정리(상식 정의)",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/movethemount\\/223415321506",\n\t\t\t"description":"<b>홍준표<\\/b>가 연일 막말을 쏟아내고 있다. 부쩍 심해진 <b>홍준표<\\/b> 말 때문에 블로그 글을 쓰기 시작했다. <b>홍준표<\\/b>는 내가 사는 대구의 시장인데, 공감할 수 없는 발언을 그칠줄을 모르는 상황이다. 연일 아가리파이터가... ",\n\t\t\t"bloggername":"중심잡기",\n\t\t\t"bloggerlink":"blog.naver.com\\/movethemount",\n\t\t\t"postdate":"20240414"\n\t\t},\n\t\t{\n\t\t\t"title":"<b>홍준표<\\/b> 조국 조폭들 단합대회",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/socoolo1\\/221678380767",\n\t\t\t"description":"가족 범죄단이라는 처참한 평가를 받고 결국 사퇴했다&quot; -<b>홍준표<\\/b>- <b>홍준표<\\/b>는... &quot;애초부터 깜이 안되어 나대면 철퇴를 맞는다고... 경고를 했는데도... 오십팔 인정,슨상님 추모하고... 위장우파라는 평가를 받고.... ",\n\t\t\t"bloggername":"쏘쿨",\n\t\t\t"bloggerlink":"blog.naver.com\\/socoolo1",\n\t\t\t"postdate":"20191015"\n\t\t},\n\t\t{\n\t\t\t"title":"<b>홍준표<\\/b>-이준석, 이강인 
# ...

# %%
type(text_data)
# Out:
# str

# %%
# json 데이터 형태를 -> 딕셔너리 : json.load()
json_data = json.loads(text_data)
json_data
# Out:
# {'lastBuildDate': 'Thu, 20 Jun 2024 15:57:48 +0900',
#  'total': 280308,
#  'start': 901,
#  'display': 100,
#  'items': [{'title': '<b>홍준표</b> 막말에 대한 댓글 정리(상식 정의)',
#    'link': 'https://blog.naver.com/movethemount/223415321506',
#    'description': '<b>홍준표</b>가 연일 막말을 쏟아내고 있다. 부쩍 심해진 <b>홍준표</b> 말 때문에 블로그 글을 쓰기 시작했다. <b>홍준표</b>는 내가 사는 대구의 시장인데, 공감할 수 없는 발언을 그칠줄을 모르는 상황이다. 연일 아가리파이터가... ',
#    'bloggername': '중심잡기',
#    'bloggerlink': 'blog.naver.com/movethemount',
#    'postdate': '20240414'},
#   {'title': '<b>홍준표</b> 조국 조폭들 단합대회',
#    'link': 'https://blog.naver.com/socoolo1/221678380767',
#    'description': '가족 범죄단이라는 처참한 평가를 받고 결국 사퇴했다&quot; -<b>홍준표</b>- <b>홍준표</b>는... &quot;애초부터 깜이 안되어 나대면 철퇴를 맞는다고... 경고를 했는데도... 오십팔 인정,슨상님 추모하고... 위장우파라는 평가를 받고.... ',
#    'bloggername': '쏘쿨',
#    'bloggerlink': 'blog.naver.com/socoolo1',
#    'postdate': '20191015'},
#   {'title': '<b>홍준표</b>-이준석, 이강인 둘러싼 공방...국민들의 시선은?',
#    'link': 'https://blog.naver.com/waaabaaa/223364304735',
# ...

# %%
type(json_data)
# Out:
# dict

# %%
json_data['items']
# Out:
# [{'title': '<b>홍준표</b> 막말에 대한 댓글 정리(상식 정의)',
#   'link': 'https://blog.naver.com/movethemount/223415321506',
#   'description': '<b>홍준표</b>가 연일 막말을 쏟아내고 있다. 부쩍 심해진 <b>홍준표</b> 말 때문에 블로그 글을 쓰기 시작했다. <b>홍준표</b>는 내가 사는 대구의 시장인데, 공감할 수 없는 발언을 그칠줄을 모르는 상황이다. 연일 아가리파이터가... ',
#   'bloggername': '중심잡기',
#   'bloggerlink': 'blog.naver.com/movethemount',
#   'postdate': '20240414'},
#  {'title': '<b>홍준표</b> 조국 조폭들 단합대회',
#   'link': 'https://blog.naver.com/socoolo1/221678380767',
#   'description': '가족 범죄단이라는 처참한 평가를 받고 결국 사퇴했다&quot; -<b>홍준표</b>- <b>홍준표</b>는... &quot;애초부터 깜이 안되어 나대면 철퇴를 맞는다고... 경고를 했는데도... 오십팔 인정,슨상님 추모하고... 위장우파라는 평가를 받고.... ',
#   'bloggername': '쏘쿨',
#   'bloggerlink': 'blog.naver.com/socoolo1',
#   'postdate': '20191015'},
#  {'title': '<b>홍준표</b>-이준석, 이강인 둘러싼 공방...국민들의 시선은?',
#   'link': 'https://blog.naver.com/waaabaaa/223364304735',
# ...

# %%
len(json_data['items'])
# Out:
# 100

# %%
import pandas as pd

df= pd.DataFrame(json_data['items'])
df
# Out:
#                                                 title  \
# 0                      <b>홍준표</b> 막말에 대한 댓글 정리(상식 정의)
# 1                              <b>홍준표</b> 조국 조폭들 단합대회
# 2              <b>홍준표</b>-이준석, 이강인 둘러싼 공방...국민들의 시선은?
# 3         [집회] 박정희우상화사업 지원 조례 부결촉구 및 <b>홍준표</b>시장...
# 4   <b>홍준표</b> &quot;의사는 공인, 타협하라&quot;... 임현택 &qu...
# ..                                                ...
# 95                           <b>홍준표</b> 막말에 대한 일부 미러링
# 96  힘든 상태', 윤석열 '서운...', <b>홍준표</b> '일신이나 걱정하는 사람...'
# 97  '보수 결집' 강조하는 황우여, '8월 전대' 가능성 시사...<b>홍준표</b>...
# 98                <b>홍준표</b>, 자신 있으면 시장 그만두고 당에 헌신해야”
# 99                 윤영찬‧김해영‧조정훈‧<b>홍준표</b>…죽음 뒤의 선동 정치
#
#                                                 link  \
# 0   https://blog.naver.com/movethemount/223415321506
# 1       https://blog.naver.com/socoolo1/221678380767
# 2       https://blog.naver.com/waaabaaa/223364304735
# 3     https://blog.naver.com/shinwh1201/223425674759
# ...

# %%
df.to_csv('naver_api.csv',encoding='UTF-8-sig')

# %%
n=2
sum(i**2 for i in range(2, n+1, 2))
# Out:
# 4
