# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
# 오리이미지 불러오기
duck_img = Image.open("오리이미지.webp")

# %%
img_array = np.array(duck_img)

# %%
img_array # R, G, B
## 가로, 세로, 색깔 -> 3차원데이터
# 영상 -> 가로, 세로, 색깔, 프레임 -> 4차원 데이터
# Out:
# array([[[252, 255, 255],
#         [252, 255, 255],
#         [252, 255, 255],
#         ...,
#         [253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255]],
#
#        [[252, 255, 255],
#         [252, 255, 255],
#         [252, 255, 255],
#         ...,
#         [253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255]],
#
#        [[252, 255, 255],
#         [252, 255, 255],
#         [252, 255, 255],
#         ...,
#         [253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [252, 255, 254],
#         [252, 255, 254],
#         [252, 255, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [252, 255, 254],
#         [252, 255, 254],
#         [252, 255, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
tmpList=[1,2,3,4] # 1차원 데이터
tmpList2=[[1,2],[3,4],[5,6]]# 2차원 데이터

# %% [markdown]
# ### 넘파이 명령어 다뤄보기

# %%
img_array_test =img_array.copy()

# %%
img_array_test[:,:,1] = 0

# %%
plt.imshow(img_array_test)

# %%
img_array_test2 =img_array.copy()
img_array_test2-=30

# %%
plt.imshow(img_array_test2)

# %% [markdown]
# ### 1. numpy 배열 만들어보기

# %%
data=np.array([1,2,3,4,5])
data
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(data)
# Out:
# numpy.ndarray

# %%
data.ndim
# Out:
# 1

# %%
data_2=np.array([[1,2,3],
                 [4,5,6]]
                 )
data_2.ndim
# Out:
# 2

# %%
data_2.shape
# Out:
# (2, 3)

# %%
data_3=data_2.reshape(3,2)
data_3
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
data_2.resize((3,2))

# %%
data_2
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
#타입바꾸기
data_4=data_2.astype("int32")

# %%
data_4.dtype
# Out:
# dtype('int32')

# %%
img_array.shape
# Out:
# (1024, 1024, 3)

# %%
plt.imshow(img_array[200:800,200:800,:])
