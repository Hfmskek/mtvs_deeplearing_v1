# %%
# 1. 모듈 임포트
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver import Keys

# %%
# 2-1. 드라이버 옵션 설정 및 브라우저 띄우기
chrom_options = webdriver.ChromeOptions()
chrom_options.add_experimental_option('detach', True)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), 
                          options=chrom_options)

# %%
# 3. 주소 이동
url = "https://play.google.com/store/apps/details?id=com.devsisters.CookieRunForKakao&hl=ko-KR"
driver.get(url)
time.sleep(2)

# %%
button_selector = "#yDmH0d > c-wiz.SSPGKf.Czez9d > div > div > div:nth-child(1) > div > div.wkMJlb.YWi3ub > div > div.qZmL0 > div:nth-child(1) > c-wiz:nth-child(4) > section > header > div > div:nth-child(2) > button"
button = driver.find_element(By.CSS_SELECTOR, button_selector)
button.click
buttons = driver.find_elements(By.CSS_SELECTOR, ".VfPpkd-Bz112c-LgbsSe")

# %%
# 5-2. 리뷰 더보기 클릭
buttons = driver.find_elements(By.CSS_SELECTOR, ".VfPpkd-Bz112c-LgbsSe")
print(len(buttons)) # 여러개 버튼 확인
# Out:
# 14

# %%
# 5-3. 리뷰 더보기 버튼 선택후 클릭
for item in buttons:
    if item.get_attribute("aria-label") == "평가 및 리뷰 자세히 알아보기":
        item.click()
        break

# %%
# 6-1. 리뷰 확인
reviews = driver.find_elements(By.CSS_SELECTOR, "div.h3YV2d")
print(len(reviews)) # 총 23개 밖에 안됨. 스크롤 다운이 필요
# Out:
# 23

# %%
for item in reviews:
    print(item.text)
# Out:
# 예전에는 안그랬던것같은데 최근에는 점프버튼 씹히는 현상이 심합니다. 다른맵이야 점프버튼 씹혀도 생명 금방차고 그렇게 큰피해가 있는건 아니지만 얼음파도의 탑만큼은 씹힘현상이 없었으면 좋겠습니다. 열쇠 하나 충전되는데 20분 걸리고 3개 충전되는데 한시간 걸리니 다른맵보다는 버그가 없었으면하는데... 이거 혹시나해서 점프키랑 슬라이드키랑 바꿔서 플레이해봤는데 왼쪽에 어떤키로 설정하던간에 키가 씹히는건 마찬가지네요. 오른쪽은 인식이 잘되는데 업데이트후) 수정내역보니 버튼 안눌리던게 고쳐진 모양이군요 이미 다 깨서 상관없지만 플레이영상 올릴때는 굉장히 힘들었습니다
# 요즘 업데이트도 자주 하고 새로운 컨텐츠도 생겨서 재미있게 하고 있습니다. 그런데 쿠키/펫 만렙 달성시 주는 보물을 보유하고 있지 않았을 때 원래는 35크리스탈로 재구매가 가능했는데 이번 패치 이후에는 재구매가 불가능해졌더라구요. 버그인지 의도인지 모르겠으나 재구매가 가능하도록 돌려주셨으면 합니다.
# 일반맵은 아직 그런적은 없는데 얼음파도탑을 깰때 시작을 누르자마자 팅겨서 열쇠를 2~3개 날렸습니다. 이 문제는 생명이나 열쇠를 게임을 시작하자마자3~5초 안에 그만두기를 하였을때 되돌려준다면 해결되지 않을까해서 남겨봄니다. 이버그 해결해주셨음 합니다. 정말 오래전부터 사랑받는 게임이 더 오래갔음 합니다.
# 가끔 점프버턴을 눌렀는데 강제로 길게 슬라이드가 되는 현상이 나타납니다. 점프가 안될때도 자주 있네요. 한번의 실수만 있어도 기록달성이 힘든데 게임도중 이런 현상이 여러번씩 발생을 하니 스트레스 받아서 게임할 맛이 안납니다. 조속한 조치 바랍니다.
# ...

# %%
driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.END)

# %%
## 6-2. 창 클릭 후 스크롤 내리기
driver.find_element(By.CSS_SELECTOR, ".VfPpkd-P5QLlc").click()
driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.END)

# %%
reviews_number = 200

while True:
    reviews = driver.find_elements(By.CSS_SELECTOR,".h3YV2d")
    if len(reviews) < 200:
        driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.END)
        time.sleep(2)
    else:
        break

# %%
result_list = []
for item in reviews:
    result_list.append(item.text)

# %%
result_list
# Out:
# ['',
#  '',
#  '',
#  '예전에는 안그랬던것같은데 최근에는 점프버튼 씹히는 현상이 심합니다. 다른맵이야 점프버튼 씹혀도 생명 금방차고 그렇게 큰피해가 있는건 아니지만 얼음파도의 탑만큼은 씹힘현상이 없었으면 좋겠습니다. 열쇠 하나 충전되는데 20분 걸리고 3개 충전되는데 한시간 걸리니 다른맵보다는 버그가 없었으면하는데... 이거 혹시나해서 점프키랑 슬라이드키랑 바꿔서 플레이해봤는데 왼쪽에 어떤키로 설정하던간에 키가 씹히는건 마찬가지네요. 오른쪽은 인식이 잘되는데 업데이트후) 수정내역보니 버튼 안눌리던게 고쳐진 모양이군요 이미 다 깨서 상관없지만 플레이영상 올릴때는 굉장히 힘들었습니다',
#  '요즘 업데이트도 자주 하고 새로운 컨텐츠도 생겨서 재미있게 하고 있습니다. 그런데 쿠키/펫 만렙 달성시 주는 보물을 보유하고 있지 않았을 때 원래는 35크리스탈로 재구매가 가능했는데 이번 패치 이후에는 재구매가 불가능해졌더라구요. 버그인지 의도인지 모르겠으나 재구매가 가능하도록 돌려주셨으면 합니다.',
#  '일반맵은 아직 그런적은 없는데 얼음파도탑을 깰때 시작을 누르자마자 팅겨서 열쇠를 2~3개 날렸습니다. 이 문제는 생명이나 열쇠를 게임을 시작하자마자3~5초 안에 그만두기를 하였을때 되돌려준다면 해결되지 않을까해서 남겨봄니다. 이버그 해결해주셨음 합니다. 정말 오래전부터 사랑받는 게임이 더 오래갔음 합니다.',
#  '가끔 점프버턴을 눌렀는데 강제로 길게 슬라이드가 되는 현상이 나타납니다. 점프가 안될때도 자주 있네요. 한번의 실수만 있어도 기록달성이 힘든데 게임도중 이런 현상이 여러번씩 발생을 하니 스트레스 받아서 게임할 맛이 안납니다. 조속한 조치 바랍니다.',
# ...
