# %% [markdown]
# ### 1. 데이터 수집하기

# %%
# import os
# from PIL import Image
# from glob import glob
# check_list = r'C:\Projects\Python_basic\6_딥러닝\data\resnet_data\*'
# glob(check_list)


# formats = [".jpg", ".jpeg", ".png", ".webp"]

# for checkdir in glob(check_list):


#     if not os.path.exists(checkdir):
#         print(f"The directory {checkdir} does not exist.")
#     else:
#         for root, dirs, files in os.walk(checkdir):
#             for file in files:
#                 if file.lower().endswith(tuple(formats)):
#                     file_path = os.path.join(root, file)
#                     try:
#                         with Image.open(file_path) as img:
#                             img.load()
#                     except Exception as e:
#                         os.remove(file_path)
#                         print(f"An exception is raised with file: {file_path} - {e}")

# %%
from bing_image_downloader import downloader
query = "카리나"
downloader.download(query, limit=120, output_dir="../data/resnet_data", adult_filter_off=True, timeout=60)
# Out:
# [%] Downloading Images to c:\Projects\Python_basic\6_딥러닝\3_파이토치비전모델링\..\data\resnet_data\카리나
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://image.imnews.imbc.com/news/2022/enter/article/__icsFiles/afieldfile/2022/09/18/20220918070128_1e586277-48ba-4e8a-9b98-d8cdbe075d86.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://image.ytn.co.kr/osen/2021/06/1b5eb05e-2e94-4bf9-b6e3-4ced807fc00b.jpg
# [Error]Invalid image, not saving https://image.ytn.co.kr/osen/2021/06/1b5eb05e-2e94-4bf9-b6e3-4ced807fc00b.jpg
#
# [!] Issue getting: https://image.ytn.co.kr/osen/2021/06/1b5eb05e-2e94-4bf9-b6e3-4ced807fc00b.jpg
# [!] Error:: Invalid image, not saving https://image.ytn.co.kr/osen/2021/06/1b5eb05e-2e94-4bf9-b6e3-4ced807fc00b.jpg
#
# [%] Downloading Image #2 from https://news.nateimg.co.kr/orgImg/sz/2022/12/24/405360_405154_616.jpg
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
query = "차은우"
downloader.download(query, limit=120, output_dir="../data/resnet_data", adult_filter_off=True, timeout=60)
# Out:
# [%] Downloading Images to c:\Projects\Python_basic\6_딥러닝\3_파이토치비전모델링\..\data\resnet_data\차은우
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://img.sbs.co.kr/newsnet/etv/upload/2021/03/05/30000673929_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://image.ytn.co.kr/osen/2021/09/4d2ac136-c4d3-467c-b7a6-8d9eb8772a22.jpg
# [Error]Invalid image, not saving https://image.ytn.co.kr/osen/2021/09/4d2ac136-c4d3-467c-b7a6-8d9eb8772a22.jpg
#
# [!] Issue getting: https://image.ytn.co.kr/osen/2021/09/4d2ac136-c4d3-467c-b7a6-8d9eb8772a22.jpg
# [!] Error:: Invalid image, not saving https://image.ytn.co.kr/osen/2021/09/4d2ac136-c4d3-467c-b7a6-8d9eb8772a22.jpg
#
# [%] Downloading Image #2 from https://img.sbs.co.kr/newsnet/etv/upload/2022/12/22/30000813051_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.topstarnews.net/news/photo/201807/451329_103118_2234.png
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
query = "마동석"
downloader.download(query, limit=120, output_dir="../data/resnet_data", adult_filter_off=True, timeout=60)
# Out:
# [%] Downloading Images to c:\Projects\Python_basic\6_딥러닝\3_파이토치비전모델링\..\data\resnet_data\마동석
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2021/07/26/bbe2deec-47db-4866-a8ce-abb39a0a181d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://img.sbs.co.kr/newsnet/etv/upload/2022/10/20/30000798339_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://img.tvreportcdn.de/cms-content/uploads/2019/11/12/6e8ef36b-36c7-4d1c-896f-19499d54ca7d.jpg
# [Error]Invalid image, not saving https://img.tvreportcdn.de/cms-content/uploads/2019/11/12/6e8ef36b-36c7-4d1c-896f-19499d54ca7d.jpg
#
# [!] Issue getting: https://img.tvreportcdn.de/cms-content/uploads/2019/11/12/6e8ef36b-36c7-4d1c-896f-19499d54ca7d.jpg
# [!] Error:: Invalid image, not saving https://img.tvreportcdn.de/cms-content/uploads/2019/11/12/6e8ef36b-36c7-4d1c-896f-19499d54ca7d.jpg
#
# ...

# %%
from bing_image_downloader import downloader
query = "박보영"
downloader.download(query, limit=120, output_dir="../data/resnet_data", adult_filter_off=True, timeout=60)
# Out:
# [%] Downloading Images to c:\Projects\Python_basic\6_딥러닝\3_파이토치비전모델링\..\data\resnet_data\박보영
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://img.hankyung.com/photo/202308/BF.34129649.1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://img.asiatoday.co.kr/file/2018y/08m/09d/2018080901000723000049331.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://t1.daumcdn.net/news/201511/13/Edaily/20151113154238799irjy.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://dimg.donga.com/wps/NEWS/IMAGE/2021/02/16/95370818.6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://img.asiatoday.co.kr/file/2018y/02m/23d/2018022301001977900135811.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://2.bp.blogspot.com/-MS6p5ao314Y/XrZbrqO-azI/AAAAAAAAAE4/Rxr6VrmD-IoVFETijodNb7uXFlh-hbIqwCLcBGAsYHQ/s1600/2.jpg
# [%] File Downloaded !
#
# ...
