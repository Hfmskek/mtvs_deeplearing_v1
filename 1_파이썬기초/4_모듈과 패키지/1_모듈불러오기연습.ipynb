# %%
import identity_util

# %%
identity_util.user_age(1992)
# Out:
# 32

# %%
identity_util.user_gender("970322-1******")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 identity_util.user_gender("970322-1697924")
#
# File c:\Projects\Python_basic\4_모듈과 패키지\identity_util.py:7, in user_gender(min_data)
#       6 def user_gender(min_data):
# ----> 7     if int(min_data) % 2 == 0:
#       8         return "여자"
#       9     else:
#
# ValueError: invalid literal for int() with base 10: '970322-1697924'
